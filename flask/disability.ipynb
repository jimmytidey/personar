# %%
import pandas as pd

from helpers import csv_to_clean_df
from basic_demography import BasicDemography
from employment import Employment


class Disability:

    def __init__(self):
        self.df = csv_to_clean_df(
            'data/disability_by_demography_employment_status.csv')

    def add_disability_status(self, sample_df):

        sample_df['disability'] = sample_df.apply(
            self.sample_disability_by_demography_employment, axis=1)
        return sample_df

    def sample_disability_by_demography_employment(self, row):

        def age_to_age_category(age):
            print(age)
            if (age <= 15):
                return 'Aged 15 years and under'
            elif (age <= 24):
                return 'Aged 16 to 24 years'
            elif (age <= 34):
                return 'Aged 25 to 34 years'
            elif (age <= 49):
                return 'Aged 35 to 49 years'
            elif (age <= 64):
                return 'Aged 50 to 64 years'
            elif (age > 65):
                return 'Aged 65 years and over'
            else:
                return -1

        # age_to_age_category(row['age'])
        age_category = 'Aged 15 years and under'
        row['ethnicity_simplified_code'] = 1
        row['employment_status_simplified_code'] = -8
        row['gender'] = 'female'

        display(self.df.query('observation>0'))

        query = "age_category == '" + age_category + "'" + \
            " & ethnicity_simplified_code == " + str(row['ethnicity_simplified_code']) + \
            " & ltla_code == '" + row['ltla_code'] + "'" + \
            " & gender == '" + row['gender'] + "'" + \
            " & employment_status_simplified_code == " + \
                str(row['employment_status_simplified_code'])

        distribution_df = self.df.query(query)

        if (distribution_df['observation'].sum() == 0):
            disability_status = 'no data'
        else:
            sample_df = distribution_df.sample(1, weights='observation')
            disability_status = sample_df['disability_status'].values[0]

        print('------------------>disability_status')
        print(disability_status)
        return disability_status


basic_demography = BasicDemography()
disability = Disability()
employment = Employment()
sample_df = basic_demography.sample(1, 'E06000002')

sample_df = employment.add_employment(sample_df)
sample_df = disability.add_disability_status(sample_df)

display(sample_df)
# Out:
#         ltla_code      ltla_name  disability_status_code  \
# 290     E06000002  Middlesbrough                       1
# 291     E06000002  Middlesbrough                       1
# 292     E06000002  Middlesbrough                       1
# 293     E06000002  Middlesbrough                       1
# 294     E06000002  Middlesbrough                       1
# ...           ...            ...                     ...
# 220315  W06000022        Newport                       2
# 220316  W06000022        Newport                       2
# 220317  W06000022        Newport                       2
# 220318  W06000022        Newport                       2
# 220319  W06000022        Newport                       2
#
#                           disability_status  Age (6 categories) Code  \
# 290         Disabled under the Equality Act                        1
# 291         Disabled under the Equality Act                        1
# 292         Disabled under the Equality Act                        1
# 293         Disabled under the Equality Act                        1
# 294         Disabled under the Equality Act                        1
# ...                                     ...                      ...
# 220315  Not disabled under the Equality Act                        6
# 220316  Not disabled under the Equality Act                        6
# 220317  Not disabled under the Equality Act                        6
# 220318  Not disabled under the Equality Act                        6
# 220319  Not disabled under the Equality Act                        6
#
#                    age_category  employment_status_simplified_code  \
# 290     Aged 15 years and under                                 -8
# 291     Aged 15 years and under                                 -8
# 292     Aged 15 years and under                                 -8
# 293     Aged 15 years and under                                 -8
# 294     Aged 15 years and under                                 -8
# ...                         ...                                ...
# 220315   Aged 65 years and over                                  3
# 220316   Aged 65 years and over                                  3
# 220317   Aged 65 years and over                                  3
# 220318   Aged 65 years and over                                  3
# 220319   Aged 65 years and over                                  3
#
#        employment_status_simplified  ethnicity_simplified_code  \
# 290                  Does not apply                          1
# 291                  Does not apply                          1
# 292                  Does not apply                          2
# 293                  Does not apply                          2
# 294                  Does not apply                          3
# ...                             ...                        ...
# 220315        Economically inactive                          3
# 220316        Economically inactive                          4
# 220317        Economically inactive                          4
# 220318        Economically inactive                          5
# 220319        Economically inactive                          5
#
#                                      ethnicity_simplified  \
# 290                   Asian, Asian British or Asian Welsh
# 291                   Asian, Asian British or Asian Welsh
# 292     Black, Black British, Black Welsh, Caribbean o...
# 293     Black, Black British, Black Welsh, Caribbean o...
# 294                       Mixed or Multiple ethnic groups
# ...                                                   ...
# 220315                    Mixed or Multiple ethnic groups
# 220316                                              White
# 220317                                              White
# 220318                                 Other ethnic group
# 220319                                 Other ethnic group
#
#         Sex (2 categories) Code  gender  observation
# 290                           1  female           71
# 291                           2    male          106
# 292                           1  female            8
# 293                           2    male           20
# 294                           1  female           40
# ...                         ...     ...          ...
# 220315                        2    male           27
# 220316                        1  female         7370
# 220317                        2    male         6106
# 220318                        1  female           21
# 220319                        2    male           25
#
# [74939 rows x 13 columns]
# age_category == 'Aged 15 years and under' & ethnicity_simplified_code == 1 & ltla_code == 'E06000002' & gender == 'female' & employment_status_simplified_code == -8
#      ltla_code      ltla_name  disability_status_code  \
# 2    E06000002  Middlesbrough                      -8
# 290  E06000002  Middlesbrough                       1
# 578  E06000002  Middlesbrough                       2
#
#                        disability_status  Age (6 categories) Code  \
# 2                         Does not apply                        1
# 290      Disabled under the Equality Act                        1
# 578  Not disabled under the Equality Act                        1
#
#                 age_category  employment_status_simplified_code  \
# 2    Aged 15 years and under                                 -8
# 290  Aged 15 years and under                                 -8
# 578  Aged 15 years and under                                 -8
#
#     employment_status_simplified  ethnicity_simplified_code  \
# 2                 Does not apply                          1
# 290               Does not apply                          1
# 578               Does not apply                          1
#
#                     ethnicity_simplified  Sex (2 categories) Code  gender  \
# 2    Asian, Asian British or Asian Welsh                        1  female
# 290  Asian, Asian British or Asian Welsh                        1  female
# 578  Asian, Asian British or Asian Welsh                        1  female
#
#      observation
# 2              0
# 290           71
# 578         1871
# ------------------>disability_status
# Not disabled under the Equality Act
#      ltla_code      ltla_name  ethnicity_code      ethnicity  \
# 607  E06000002  Middlesbrough              13  White British
#
#      Age (9 categories) Code         age_category  Sex (2 categories) Code  \
# 607                        7  Aged 50 to 64 years                        2
#
#     gender  observation ethnicity_code_simplified  age  notes employment  \
# 607   male        11572                         4   60    8.0   Employed
#
#      employment_status_simplified_code                           disability
# 607                                  1  Not disabled under the Equality Act
